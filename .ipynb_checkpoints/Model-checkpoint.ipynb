# %%
import pickle
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np 
x = pickle.load(open('x.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))
x=x/255
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(128, input_shape = x.shape[1:], activation = 'relu'))

model.add(Dense(4, activation = 'softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# model.fit(x, y, epochs=7, validation_split=0.1)
model.fit(x_train, y_train, epochs=5, validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# 24/24 [==============================] - 11s 440ms/step - loss: 1.4257 - accuracy: 0.3784 - val_loss: 0.9366 - val_accuracy: 0.6867
# Epoch 2/5
# 24/24 [==============================] - 9s 392ms/step - loss: 0.5329 - accuracy: 0.8486 - val_loss: 0.3550 - val_accuracy: 0.8916
# Epoch 3/5
# 24/24 [==============================] - 9s 383ms/step - loss: 0.2474 - accuracy: 0.9189 - val_loss: 0.3331 - val_accuracy: 0.9036
# Epoch 4/5
# 24/24 [==============================] - 10s 398ms/step - loss: 0.1410 - accuracy: 0.9514 - val_loss: 0.2352 - val_accuracy: 0.9518
# Epoch 5/5
# 24/24 [==============================] - 9s 386ms/step - loss: 0.0944 - accuracy: 0.9703 - val_loss: 0.2840 - val_accuracy: 0.9518

# %%
model.save('my_model.model')
# Out:
# WARNING:tensorflow:From C:\Users\USER\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\USER\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: my_model.model\assets

# %%
new_model = tf.keras.models.load_model('my_model.model')

# %%
from sklearn.metrics import confusion_matrix
y_pred=[]
for img in x_test:
  r=np.expand_dims(img, axis=0)
  y_pred.append(np.argmax(new_model.predict(r)))
y_pred = np.array(y_pred)
confusion_matrix(y_test, y_pred)
# Out:
# array([[20,  1,  0,  0],
#        [ 0, 20,  0,  0],
#        [ 0,  0, 22,  0],
#        [ 0,  0,  0, 20]], dtype=int64)

# %%
index = 700
r=np.expand_dims(x[index], axis=0)
predictions = new_model.predict(r)
print(np.argmax(predictions))
# Out:
# 3

# %%
import matplotlib.pyplot as plt
plt.imshow(x[index])
plt.show()
